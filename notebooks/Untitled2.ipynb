# %%
# %matplotlib inline

import netCDF4
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
root = r"C:\Users\PCUser\Desktop\2017_HowardsEast_SkyTEM\01_EM"

nc_inpath = os.path.join(root, "AUS_10021_HowardE_EM.nc")

d = netCDF4.Dataset(nc_inpath, "r")

d.groups
# Out:
# OrderedDict()

# %%
d.close
# Out:
# <function Dataset.close>

# %%
line = 313001

lines = d['line'][:]
# Out:
# masked_array(data=[100002, 100102, 100202, 100302, 100402, 100502, 100602,
#                    100702, 100802, 100902, 101002, 101102, 101202, 101303,
#                    101352, 101403, 101502, 101602, 101702, 101802, 101803,
#                    101902, 102002, 102102, 102202, 102301, 102402, 102502,
#                    102602, 102702, 102802, 102902, 103002, 200002, 200102,
#                    200202, 200252, 200302, 200352, 200402, 200502, 200602,
#                    200702, 200802, 200902, 201002, 201103, 201104, 201202,
#                    201302, 201402, 201502, 201503, 201602, 201702, 201802,
#                    201902, 202002, 202102, 202202, 202203, 202302, 202303,
#                    202402, 202502, 202602, 202702, 202802, 202902, 202952,
#                    203002, 203052, 203102, 203152, 203202, 203252, 203302,
#                    203352, 203402, 203451, 203502, 203552, 203602, 203652,
# ...

# %%
d['flight_line'][:]
# Out:
# masked_array(data=[2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.,
#                    2., 2., 2., 2., 2.],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
#

#1. demonstrate subsetting line
#2. easting northing elevation
# 3. extract variables
